# %%
import re
text="Python is easy"
res=re.search('Python',text)
res=re.findall('Python',text)
print(res)
# Out:
# ['Python']

# %%
text="sql power BI"
new=re.sub("power BI","powerbi",text)
print(new)
print(text)
# Out:
# sql powerbi
# sql power BI

# %%
import re
text="order123"
data=re.findall(r'\d+',text)
print(data)
# Out:
# ['123']

# %%
import re 
text="sales:500 profits:1000"
data=re.findall(r'\d+',text)
print(data)
# Out:
# ['500', '1000']

# %%
import re
text="mail1=john123@gmail.com mail2=web@.com mail3=123.com"
data=re.search(r"\w+@+\w+\w",text)
print(data)
# Out:
# <re.Match object; span=(6, 19), match='john123@gmail'>

# %%
import re
mail1="john123@gmail.com",
mail2="web@.com",
mail3="123.com",
data1=re.search(r"\w+@+\w+\w",mail1)
data2=re.search(r"\w+@+\w+\w",mail2)
data3=re.search(r"\w+@+\w+\w",mail3)

print(data1)
print(data2)
print(data3)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[42], line 5
#       1 import re
#       2 mail1="john123@gmail.com",
#       3 mail2="web@.com",
#       4 mail3="123.com",
# ----> 5 data1=re.search(r"\w+@+\w+\w",mail1)
#       6 data2=re.search(r"\w+@+\w+\w",mail2)
#       7 data3=re.search(r"\w+@+\w+\w",mail3)
#       8
#
# File c:\Python313\Lib\re\__init__.py:177, in search(pattern, string, flags)
#     174 def search(pattern, string, flags=0):
#     175     """Scan through string looking for a match to the pattern, returning
#     176     a Match object, or None if no match was found."""
# --> 177     return _compile(pattern, flags).search(string)
#
# TypeError: expected string or bytes-like object, got 'tuple'

# %%
import re

text = "54166252226"
text1 = "57589456526545"

data = re.search(r'\d{10}', text)
data1 = re.search(r'\d{10}', text1)

print(data)
print(data1)
# Out:
# <re.Match object; span=(0, 10), match='5416625222'>
# <re.Match object; span=(0, 10), match='5758945652'>
