# %%
import csv
with open(r"C:\Users\user\Pictures\Desktop\Data_Analytics_Portfolio\Python1\File_Handling\data.csv",'w',newline='') as file:
    writer=csv.writer(file)
    writer.writerow(["INK",25])
    writer.writerow(["pencil",25])

# %%
import csv
total_sales=0
count=0
with open(r"C:\Users\user\Pictures\Desktop\Data_Analytics_Portfolio\Python1\File_Handling\data.csv",'r') as file:
    reader=csv.DictReader(file)
    for row in reader:
        totalsales=total_sales+int(row['sales'])
    count=len(row)
    print(totalsales)
average=totalsales/count
print(count)
print(average)
# Out:
# 25
# 2
# 12.5

# %%
import csv
total_sales=0
count=0
with open(r"C:\Users\user\Pictures\Desktop\Data_Analytics_Portfolio\Python1\File_Handling\data.csv",'r') as file:
    reader=csv.DictReader(file)
    for row in reader:
        totalsales=total_sales+int(row['sales'])
    print(total_sales)

# %%
try:
    O=file.open(r"C:\Users\user\Pictures\Desktop\Data_Analytics_Portfolio\Python1\File_Handling\data.csv"'r')
except:
    print('File Not Available in your dictionary system')
finally:
    print('file opened')
# Out:
# File Not Available in your dictionary system
# file opened
