# %%
Emp_name="  John Smith  "
print(Emp_name.upper())
# Out:
#   JOHN SMITH

# %%
Emp_name="  John Smith  "
print(Emp_name.lower())
# Out:
#   john smith

# %%
Emp_name="  John Smith  "
print(Emp_name.strip())
# Out:
# John Smith

# %%
Emp_name="  John Smith  "
l=len(Emp_name.strip())
print(l)
# Out:
# 10

# %%
customers = ["John", "Mary", "David"]
customers.append("Ram")
customers.append("chandran")
print(customers)
# Out:
# ['John', 'Mary', 'David', 'Ram', 'chandran']

# %%
customers = ['John', 'Mary', 'David', 'Ram', 'chandran']
print(customers.pop())
# Out:
# chandran

# %%
customers = ['John', 'Mary', 'David', 'Ram', 'chandran','zara','ashwin','dora','bheem','kaliya']
customers.sort(key=str.lower)
print(customers)
# Out:
# ['ashwin', 'bheem', 'chandran', 'David', 'dora', 'John', 'kaliya', 'Mary', 'Ram', 'zara']

# %%
customers = ['John', 'Mary', 'David', 'Ram', 'chandran','zara','ashwin','dora','bheem','kaliya']
count=len(customers)
print(count)
# Out:
# 10

# %%
customers = ['John', 'Mary', 'David', 'Ram', 'chandran','zara','ashwin','dora','bheem','kaliya']
customers[0],customers[9]
# Out:
# ('John', 'kaliya')

# %%
company = ("ABC Support Services", "Coimbatore", 2015)
print(company)
# Out:
# ('ABC Support Services', 'Coimbatore', 2015)

# %%
company = ("ABC Support Services", "Coimbatore", 2015)
print("company name:",company[0])
print("company city:",company[1])
print("company starts:",company[2])
# Out:
# company name: ABC Support Services
# company city: Coimbatore
# company starts: 2015

# %%
current_year=2026
company = ("ABC Support Services", "Coimbatore", 2015)
company_age=(current_year- company[2])
print("company_age:",company_age,"years")
# Out:
# company_age: 11 years

# %%
cities = {"Chennai", "Coimbatore", "Madurai", "Chennai"}
print(cities)
# Out:
# {'Madurai', 'Coimbatore', 'Chennai'}

# %%
cities = {"Chennai", "Coimbatore", "Madurai", "Chennai"}
count=len(cities)
print(count)
# Out:
# 3

# %%
cities = {"Chennai", "Coimbatore", "Madurai", "Chennai"}
cities.add("Dharmapuri")
cities.add("Tiruupur")
cities.add("vellore")
print(cities)
# Out:
# {'Tiruupur', 'Dharmapuri', 'Chennai', 'Coimbatore', 'Madurai', 'vellore'}

# %%
cities = {'Tiruupur', 'Dharmapuri', 'Chennai', 'Coimbatore', 'Madurai', 'vellore'}
cities.pop()
print(cities)
# Out:
# {'Tiruupur', 'Chennai', 'Dharmapuri', 'Coimbatore', 'vellore'}

# %%
cities = {"Chennai", "Coimbatore", "Madurai", "Chennai"}
city="Coimbatore"
if city in cities:
    print("city exist")
else:
    print("city not exist")
# Out:
# city exist

# %%
customer = {
    "Customer_ID": "C101",
    "Name": "John",
    "City": "Chennai",
    "Satisfaction_Rating": 4.5
}
print(customer)
# Out:
# {'Customer_ID': 'C101', 'Name': 'John', 'City': 'Chennai', 'Satisfaction_Rating': 4.5}

# %%
customer = {
    "Customer_ID": "C101",
    "Name": "John",
    "City": "Chennai",
    "Satisfaction_Rating": 4.5
}
customer.update({"Satisfaction_Rating": 4.9})
print(customer)
# Out:
# {'Customer_ID': 'C101', 'Name': 'John', 'City': 'Chennai', 'Satisfaction_Rating': 4.9}

# %%
customer = {
    "Customer_ID": "C101",
    "Name": "John",
    "City": "Chennai",
    "Satisfaction_Rating": 4.5
}
customer["Membership Type"] = "Gold"

for key, value in customer.items():
    print(key, ":", value)
for field in customer:
    print(field)
# Out:
# Customer_ID : C101
# Name : John
# City : Chennai
# Satisfaction_Rating : 4.5
# Membership Type : Gold
# Customer_ID
# Name
# City
# Satisfaction_Rating
# Membership Type

# %%
customer = {
    "Customer_ID": "C101",
    "Name": "John",
    "City": "Chennai",
    "Satisfaction_Rating": 4.5
}
customer["Membership Type"] = "Gold"

for key, value in customer.items():
    print(key, ":", value)

customer.pop("City")
# Out:
# Customer_ID : C101
# Name : John
# City : Chennai
# Satisfaction_Rating : 4.5
# Membership Type : Gold
# 'Chennai'

# %%
customer = {
    "Customer_ID": "C101",
    "Name": "John",
    "City": "Chennai",
    "Satisfaction_Rating": 4.5
}
print(key)
print(value)
# Out:
# Membership Type
# Gold

# %%
customer = {
    "Customer_ID": "C101",
    "Name": "John",
    "City": "Chennai",
    "Satisfaction_Rating": 4.5
}
for key,value in customer.items():
    print(key)
    print(value)
# Out:
# Customer_ID
# C101
# Name
# John
# City
# Chennai
# Satisfaction_Rating
# 4.5
