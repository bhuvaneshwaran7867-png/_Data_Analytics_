# %%
class student:
    def __init__(self,name,RollNo,Branch):
        self.name= name
        self.RollNo=RollNo
        self.Branch=Branch
s1=student("Bhuvaneshwaran",'22CS006',"CSE")
print(s1)
print(s1.name)
print(s1.RollNo)
print(s1.Branch)
# Out:
# ...
# Bhuvaneshwaran
# 22CS006
# CSE

# %%
class student:
    def __init__(self,name,RollNo,Branch):
        self.name= name
        self.RollNo=RollNo
        self.Branch=Branch
        
    def tell_details(self):  
     return ((f"My name is:{self.name}"),
            (f"My RollNo is:{self.RollNo}"),
            (f"My Branch is:{self.Branch}"))
     
s1=student("Bhuvaneshwaran",'22CS006',"CSE")
print(s1.tell_details)
# Out:
# <bound method student.tell_details of <__main__.student object at 0x000001D0243D8830>>

# %%
class Employee:
    def work(self):
        print("working")
class Manager(Employee):
    pass
m=Manager()
m.work()
# Out:
# working

# %%
class Employee:
    def __init__(self, name, salary):
        self.name = name
        self.salary = salary

E = Employee("ram", 50000)
E.salary = 80000
print(E.salary)
# Out:
# 80000

# %%
class Employee:
    def __int__(self,name):
        self.name=name
        self.__salary=50000
E=Employee('Ram')
print(E.__salary)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[51], line 5
#       1 class Employee:
#       2     def __int__(self,name):
#       3         self.name=name
#       4         self.__salary=50000
# ----> 5 E=Employee('Ram')
#       6 print(E.__salary)
#
# TypeError: Employee() takes no arguments

# %%
class student:
    def __init__(self,name,marks):
        self.name = name
        self.__mark= 0

s1= student("ram")

print(s1.student)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[50], line 6
#       2     def __init__(self,name,marks):
#       3         self.name = name
#       4         self.__mark= 0
#       5
# ----> 6 s1= student("ram")
#       7
#       8 print(s1.student)
#
# TypeError: student.__init__() missing 1 required positional argument: 'marks'
