# %%
try:
    age=int(input("Enter age: "))
    print(age)
except:
    print('invalid age')
# Out:
# invalid age

# %%
try:
    age=int(input("Enter your age:")) 

except ValueError:
    print('invalid age')
except SyntaxError:
    print('invalid syntax')

# %%
try:
    print('processing')
except:
    print('Error')
finally:
    print('completed')
# Out:
# processing
# completed
