# %%
from abc import ABC,abstractmethod
class Employee:
    @abstractmethod
    def work(self):
        print("working")
class developer():
    def work(self):
        print("developing")
class HR():
    def work(self):
        print("Recruting")
dev=developer()
hr=HR()
dev.work()
hr.work()
# Out:
# developing
# Recruting

# %%
class data_analyst:
    def work(self):
        return("Analysing")
data=data_analyst()
data.work()
print(data.work())
# Out:
# 'Analysing'
