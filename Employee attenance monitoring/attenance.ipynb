# %%
for i in range (1,11):
    attendance=int(input("Employee attendance: "))

if attendance == -1:
    print("Data entry stopped.")
     

if attendance == 0:
        print(f"Employee {attendance}: Record skipped.")
        

if attendance > 100:
        pass



if attendance >=90:
        print("Excellent")
elif attendance >75 <=89:
        print("Good")
elif attendance <75:
        print("Improvement Required")





print("\nAttendance Summary")
print("")
print("Total Employees Processed :", processed)
print("Excellent :", excellent)
print("Good :", good)
print("Improvement Required :", improvement)
# Out:
# Improvement Required
#
# Attendance Summary
#
# Total Employees Processed : 7
# Excellent : 1
# Good : 2
# Improvement Required : 4
